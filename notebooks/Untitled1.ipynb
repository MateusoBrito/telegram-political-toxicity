# %%
import pandas as pd

df = pd.read_parquet("../data/processed/messages_with_language")

# %%
df
# Out:
#            id          group_name  \
# 0     2471233  channel_1698707268
# 1     2491481  channel_1698707268
# 2       62462  channel_1851234959
# 3       69480  channel_1851234959
# 4      729382  channel_1522129471
# ...       ...                 ...
# 5445   950728  channel_1370023850
# 5446     7840  channel_1653515977
# 5447   839415  channel_1887031669
# 5448   944034  channel_1370023850
# 5449    30361  channel_1919584255
#
#                                                    text   timestamp  \
# 0     Isn’t anyone talking yet about a blockade or o...  1699708879
# 1     Best meme since Bernie Sanders' mittens. It wi...  1700435904
# 2     One drop rule would mean people who get 0.01% ...  1699673884
# 3      Reconquista happened and so it will happen again  1700436061
# 4                                 Over your dead bodies  1700093043
# ...                                                 ...         ...
# 5445  🐆 with RABV. She self is inmmune but the one l...  1726578271
# ...

# %%
df_en = df[df['language'] == 'en'].copy()
print(f"Número de mensagens em inglês: {len(df_en)}")
# Out:
# Número de mensagens em inglês: 5107

# %%
df_en.head(100)
# Out:
#           id          group_name  \
# 0    2471233  channel_1698707268
# 2      62462  channel_1851234959
# 3      69480  channel_1851234959
# 5     241328  channel_1526112366
# 6     317956  channel_1568299437
# ..       ...                 ...
# 106   140910  channel_1409345080
# 107   131695  channel_1235779695
# 108   633570  channel_1202500264
# 109   465342  channel_1263412188
# 110   110495  channel_1161666782
#
#                                                   text   timestamp  \
# 0    Isn’t anyone talking yet about a blockade or o...  1699708879
# 2    One drop rule would mean people who get 0.01% ...  1699673884
# 3     Reconquista happened and so it will happen again  1700436061
# 5    The 248th Marine Corps Birthday Message: https...  1698995714
# 6    Bald eagle, October 29, 2023, Brazoria County,...  1698861013
# ..                                                 ...         ...
# 106  Gript\nON THIS DAY: 15 NOVEMBER 1881: Birth of...  1700040111
# ...

# %%
df_nen = df[df['language'] != 'en'].copy()
print(f"Número de mensagens em outro idioma: {len(df_nen)}")
# Out:
# Número de mensagens em outro idioma: 343

# %%
df_nen.head(30)
# Out:
#           id          group_name  \
# 1    2491481  channel_1698707268
# 4     729382  channel_1522129471
# 12    409599  channel_1595174369
# 60     56408  channel_1857065732
# 72     96111  channel_1438734111
# 76    113146  channel_1735249568
# 80     14990  channel_1745006047
# 95     21091  channel_1813467025
# 96       444  channel_1803107119
# 97    112719  channel_1758820844
# 100   460483  channel_1263412188
# 117   463895  channel_1263412188
# 120    92390  channel_1458759868
# 136   425166  channel_1441246337
# 156    81337  channel_1683101758
# 185  1073400  channel_1556404753
# 197     7482  channel_1643755063
# 237   106383  channel_1700320039
# 238    14019  channel_1227682995
# 248   347537  channel_1301697336
# 266    48189  channel_1623527278
# 267   269706  channel_1671860401
# 268   122091  channel_1904302842
# 283   947125  channel_1791839714
# 294      792  channel_1228507102
# 303    75404  channel_1420727748
# 355   342252  channel_1568299437
# ...

# %%
df.to_csv("../reports/sample_test_english.csv")
